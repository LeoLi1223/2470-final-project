# %%
from caption import memeify_image
from PIL import Image
import os

# %%
IMG_DIR = "../memes900k/images"
img_pil = Image.open(os.path.join(IMG_DIR, 'anxiety-cat.jpg'))
memeify_image(img_pil, "hi", "bye")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300>

# %%
img_pil = Image.open(os.path.join(IMG_DIR, 'business-cat.jpg'))
memeify_image(img_pil, "need to work", "downvote")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300>

# %%
img_pil = Image.open(os.path.join(IMG_DIR, 'grumpy-cat-santa-hat.jpg'))
memeify_image(img_pil, "merry christmas", "no")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300>

# %%
img_pil = Image.open(os.path.join(IMG_DIR, 'batman-slap-robin.jpg'))
memeify_image(img_pil, "you mean to go to the world", "shut up")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300>
